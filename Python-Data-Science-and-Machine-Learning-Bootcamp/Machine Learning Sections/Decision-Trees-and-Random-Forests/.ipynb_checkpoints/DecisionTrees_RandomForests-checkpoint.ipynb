# %% [markdown]
# # Decision Trees and Random Forests

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
# %matplotlib inline

# %%
df = pd.read_csv('kyphosis.csv')

# %%
df.head()
# Out:
#   Kyphosis  Age  Number  Start
# 0   absent   71       3      5
# 1   absent  158       3     14
# 2  present  128       4      5
# 3   absent    2       5      1
# 4   absent    1       4     15

# %%
sns.pairplot(df,hue='Kyphosis',palette='Set1')

# %%
#import train test split
from sklearn.model_selection import train_test_split

# %%
X= df.drop('Kyphosis', axis=1)
y=df['Kyphosis']

# %%
X_train, X_test, y_train, y_test = train_test_split(
X, y, test_size=0.30)

# %%
#create decision trees
from sklearn.tree import DecisionTreeClassifier

# %%
dtree=DecisionTreeClassifier()

# %%
dtree.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
pred= dtree.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
print(classification_report(y_test, pred))
# Out:
#              precision    recall  f1-score   support
#
#      absent       0.80      0.76      0.78        21
#     present       0.00      0.00      0.00         4
#
# avg / total       0.67      0.64      0.66        25

# %%
print(sns.heatmap(confusion_matrix(y_test, pred), annot=True,cmap='YlGnBu'))
# Out:
# AxesSubplot(0.125,0.125;0.62x0.755)

# %%
import imblearn
from imblearn.over_sampling import SMOTE

# %%
#from imblearn.datasets import make_imbalance
#X_resampled, y_resampled = make_imbalance(X, y, ratio=0.1,min_c='Kyphosis', random_state=250)
#smote= SMOTE(kind='regular')

# %%
#X_sm, y_sm = smote.fit_sample(X_resampled, y_resampled)

# %%
#X_smtrain, X_smtest, y_smtrain, y_smtest = train_test_split(
#X_sm, y_sm, test_size=0.30, random_state=110)

# %%
#print(classification_report(y_smtest, pred2))

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier(n_estimators=100)
rfc.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
rfc_pred = rfc.predict(X_test)

# %%
print(confusion_matrix(y_test,rfc_pred))
# Out:
# [[21  0]
#  [ 1  3]]

# %%
print(classification_report(y_test,rfc_pred))
# Out:
#              precision    recall  f1-score   support
#
#      absent       0.95      1.00      0.98        21
#     present       1.00      0.75      0.86         4
#
# avg / total       0.96      0.96      0.96        25
